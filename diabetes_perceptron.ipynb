# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
print (df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].mean())
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000   79.799479  33.6
# 1              1     85.0           66.0      29.000000   79.799479  26.6
# 2              8    183.0           64.0      20.536458   79.799479  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0           40.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10    101.0           76.0      48.000000  180.000000  32.9
# 764            2    122.0           70.0      27.000000   79.799479  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0           60.0      20.536458   79.799479  30.1
# 767            1     93.0           70.0      31.000000   79.799479  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
X= df.drop("Outcome", axis=1)
y= df[["Outcome"]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =train_test_split(X, y,test_size=0.3,random_state=0)

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\laptopcheckout\anaconda3\lib\site-packages (2.8.0)

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\laptopcheckout\anaconda3\lib\site-packages (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (0.24.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: setuptools in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (2.8.0.dev2021122109)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (1.43.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.26.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.0.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\laptopcheckout\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(12, input_dim = 8,activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
#compile
model.compile(loss='binary_crossentropy', optimizer = 'adam', metrics = ['Accuracy'])

# %%
#training a model
history=model.fit(X_train, y_train, epochs = 150, verbose =2, batch_size = 10)
# Out:
# Epoch 1/150
# 54/54 - 0s - loss: 10.7223 - Accuracy: 0.5866 - 280ms/epoch - 5ms/step
# Epoch 2/150
# 54/54 - 0s - loss: 1.1097 - Accuracy: 0.5251 - 70ms/epoch - 1ms/step
# Epoch 3/150
# 54/54 - 0s - loss: 0.8376 - Accuracy: 0.5661 - 80ms/epoch - 1ms/step
# Epoch 4/150
# 54/54 - 0s - loss: 0.7741 - Accuracy: 0.5400 - 78ms/epoch - 1ms/step
# Epoch 5/150
# 54/54 - 0s - loss: 0.8014 - Accuracy: 0.6611 - 75ms/epoch - 1ms/step
# Epoch 6/150
# 54/54 - 0s - loss: 0.7170 - Accuracy: 0.6723 - 79ms/epoch - 1ms/step
# Epoch 7/150
# 54/54 - 0s - loss: 0.7236 - Accuracy: 0.6853 - 73ms/epoch - 1ms/step
# Epoch 8/150
# 54/54 - 0s - loss: 0.7481 - Accuracy: 0.6778 - 70ms/epoch - 1ms/step
# Epoch 9/150
# 54/54 - 0s - loss: 0.6695 - Accuracy: 0.6890 - 71ms/epoch - 1ms/step
# Epoch 10/150
# 54/54 - 0s - loss: 0.6621 - Accuracy: 0.6816 - 67ms/epoch - 1ms/step
# Epoch 11/150
# 54/54 - 0s - loss: 0.6476 - Accuracy: 0.6890 - 68ms/epoch - 1ms/step
# Epoch 12/150
# 54/54 - 0s - loss: 0.6347 - Accuracy: 0.6816 - 59ms/epoch - 1ms/step
# Epoch 13/150
# 54/54 - 0s - loss: 0.6187 - Accuracy: 0.6927 - 45ms/epoch - 833us/step
# Epoch 14/150
# 54/54 - 0s - loss: 0.6181 - Accuracy: 0.6909 - 56ms/epoch - 1ms/step
# Epoch 15/150
# 54/54 - 0s - loss: 0.6185 - Accuracy: 0.6778 - 46ms/epoch - 855us/step
# Epoch 16/150
# 54/54 - 0s - loss: 0.6196 - Accuracy: 0.6816 - 50ms/epoch - 930us/step
# Epoch 17/150
# 54/54 - 0s - loss: 0.6139 - Accuracy: 0.6965 - 53ms/epoch - 990us/step
# Epoch 18/150
# 54/54 - 0s - loss: 0.5931 - Accuracy: 0.6909 - 51ms/epoch - 944us/step
# Epoch 19/150
# 54/54 - 0s - loss: 0.6152 - Accuracy: 0.7020 - 42ms/epoch - 783us/step
# Epoch 20/150
# 54/54 - 0s - loss: 0.5956 - Accuracy: 0.6909 - 48ms/epoch - 893us/step
# Epoch 21/150
# 54/54 - 0s - loss: 0.6150 - Accuracy: 0.6834 - 47ms/epoch - 865us/step
# Epoch 22/150
# 54/54 - 0s - loss: 0.6024 - Accuracy: 0.6909 - 45ms/epoch - 839us/step
# Epoch 23/150
# 54/54 - 0s - loss: 0.6249 - Accuracy: 0.6816 - 56ms/epoch - 1ms/step
# Epoch 24/150
# 54/54 - 0s - loss: 0.6072 - Accuracy: 0.6965 - 48ms/epoch - 893us/step
# Epoch 25/150
# 54/54 - 0s - loss: 0.6072 - Accuracy: 0.6890 - 78ms/epoch - 1ms/step
# Epoch 26/150
# 54/54 - 0s - loss: 0.6191 - Accuracy: 0.6853 - 79ms/epoch - 1ms/step
# Epoch 27/150
# 54/54 - 0s - loss: 0.6275 - Accuracy: 0.6890 - 57ms/epoch - 1ms/step
# Epoch 28/150
# 54/54 - 0s - loss: 0.5924 - Accuracy: 0.6946 - 58ms/epoch - 1ms/step
# Epoch 29/150
# 54/54 - 0s - loss: 0.6082 - Accuracy: 0.6890 - 50ms/epoch - 935us/step
# Epoch 30/150
# 54/54 - 0s - loss: 0.5871 - Accuracy: 0.6927 - 59ms/epoch - 1ms/step
# Epoch 31/150
# 54/54 - 0s - loss: 0.5991 - Accuracy: 0.6983 - 59ms/epoch - 1ms/step
# Epoch 32/150
# 54/54 - 0s - loss: 0.6025 - Accuracy: 0.7020 - 57ms/epoch - 1ms/step
# Epoch 33/150
# 54/54 - 0s - loss: 0.6221 - Accuracy: 0.6853 - 54ms/epoch - 1ms/step
# Epoch 34/150
# 54/54 - 0s - loss: 0.5810 - Accuracy: 0.6946 - 59ms/epoch - 1ms/step
# Epoch 35/150
# 54/54 - 0s - loss: 0.6158 - Accuracy: 0.6834 - 53ms/epoch - 974us/step
# Epoch 36/150
# 54/54 - 0s - loss: 0.6008 - Accuracy: 0.6834 - 70ms/epoch - 1ms/step
# Epoch 37/150
# 54/54 - 0s - loss: 0.6075 - Accuracy: 0.6965 - 74ms/epoch - 1ms/step
# Epoch 38/150
# 54/54 - 0s - loss: 0.6131 - Accuracy: 0.6778 - 71ms/epoch - 1ms/step
# Epoch 39/150
# 54/54 - 0s - loss: 0.6149 - Accuracy: 0.6983 - 57ms/epoch - 1ms/step
# Epoch 40/150
# 54/54 - 0s - loss: 0.6091 - Accuracy: 0.6741 - 57ms/epoch - 1ms/step
# Epoch 41/150
# 54/54 - 0s - loss: 0.5833 - Accuracy: 0.7039 - 55ms/epoch - 1ms/step
# Epoch 42/150
# 54/54 - 0s - loss: 0.5979 - Accuracy: 0.6890 - 55ms/epoch - 1ms/step
# Epoch 43/150
# 54/54 - 0s - loss: 0.5695 - Accuracy: 0.6890 - 51ms/epoch - 949us/step
# Epoch 44/150
# 54/54 - 0s - loss: 0.6192 - Accuracy: 0.6741 - 55ms/epoch - 1ms/step
# Epoch 45/150
# 54/54 - 0s - loss: 0.6073 - Accuracy: 0.6872 - 51ms/epoch - 948us/step
# Epoch 46/150
# 54/54 - 0s - loss: 0.5926 - Accuracy: 0.7020 - 55ms/epoch - 1ms/step
# Epoch 47/150
# 54/54 - 0s - loss: 0.6115 - Accuracy: 0.6797 - 53ms/epoch - 983us/step
# Epoch 48/150
# 54/54 - 0s - loss: 0.5875 - Accuracy: 0.6872 - 52ms/epoch - 967us/step
# Epoch 49/150
# 54/54 - 0s - loss: 0.6015 - Accuracy: 0.6983 - 66ms/epoch - 1ms/step
# Epoch 50/150
# 54/54 - 0s - loss: 0.6054 - Accuracy: 0.6872 - 60ms/epoch - 1ms/step
# Epoch 51/150
# 54/54 - 0s - loss: 0.5952 - Accuracy: 0.6946 - 52ms/epoch - 964us/step
# Epoch 52/150
# 54/54 - 0s - loss: 0.5912 - Accuracy: 0.6909 - 54ms/epoch - 1ms/step
# Epoch 53/150
# 54/54 - 0s - loss: 0.5941 - Accuracy: 0.6946 - 52ms/epoch - 961us/step
# Epoch 54/150
# 54/54 - 0s - loss: 0.5974 - Accuracy: 0.6909 - 50ms/epoch - 917us/step
# Epoch 55/150
# 54/54 - 0s - loss: 0.5981 - Accuracy: 0.6890 - 54ms/epoch - 999us/step
# Epoch 56/150
# 54/54 - 0s - loss: 0.5971 - Accuracy: 0.6741 - 47ms/epoch - 866us/step
# Epoch 57/150
# 54/54 - 0s - loss: 0.6078 - Accuracy: 0.6853 - 49ms/epoch - 901us/step
# Epoch 58/150
# 54/54 - 0s - loss: 0.5818 - Accuracy: 0.6946 - 54ms/epoch - 993us/step
# Epoch 59/150
# 54/54 - 0s - loss: 0.5778 - Accuracy: 0.6927 - 56ms/epoch - 1ms/step
# Epoch 60/150
# 54/54 - 0s - loss: 0.5760 - Accuracy: 0.6927 - 51ms/epoch - 939us/step
# Epoch 61/150
# 54/54 - 0s - loss: 0.5995 - Accuracy: 0.6834 - 49ms/epoch - 907us/step
# Epoch 62/150
# 54/54 - 0s - loss: 0.5940 - Accuracy: 0.6946 - 53ms/epoch - 981us/step
# Epoch 63/150
# 54/54 - 0s - loss: 0.5901 - Accuracy: 0.7020 - 58ms/epoch - 1ms/step
# Epoch 64/150
# 54/54 - 0s - loss: 0.5852 - Accuracy: 0.6946 - 62ms/epoch - 1ms/step
# Epoch 65/150
# 54/54 - 0s - loss: 0.5899 - Accuracy: 0.6909 - 54ms/epoch - 993us/step
# Epoch 66/150
# 54/54 - 0s - loss: 0.5870 - Accuracy: 0.6853 - 52ms/epoch - 955us/step
# Epoch 67/150
# 54/54 - 0s - loss: 0.5858 - Accuracy: 0.6946 - 48ms/epoch - 894us/step
# Epoch 68/150
# 54/54 - 0s - loss: 0.5730 - Accuracy: 0.7095 - 49ms/epoch - 900us/step
# Epoch 69/150
# 54/54 - 0s - loss: 0.5968 - Accuracy: 0.6872 - 48ms/epoch - 886us/step
# Epoch 70/150
# 54/54 - 0s - loss: 0.5689 - Accuracy: 0.6965 - 48ms/epoch - 890us/step
# Epoch 71/150
# 54/54 - 0s - loss: 0.5929 - Accuracy: 0.6890 - 49ms/epoch - 906us/step
# Epoch 72/150
# 54/54 - 0s - loss: 0.5709 - Accuracy: 0.7076 - 48ms/epoch - 888us/step
# Epoch 73/150
# 54/54 - 0s - loss: 0.5753 - Accuracy: 0.6909 - 49ms/epoch - 899us/step
# Epoch 74/150
# 54/54 - 0s - loss: 0.5648 - Accuracy: 0.6909 - 50ms/epoch - 930us/step
# Epoch 75/150
# 54/54 - 0s - loss: 0.5674 - Accuracy: 0.6909 - 49ms/epoch - 906us/step
# Epoch 76/150
# 54/54 - 0s - loss: 0.6010 - Accuracy: 0.6965 - 49ms/epoch - 900us/step
# Epoch 77/150
# 54/54 - 0s - loss: 0.5798 - Accuracy: 0.6909 - 51ms/epoch - 943us/step
# Epoch 78/150
# 54/54 - 0s - loss: 0.5693 - Accuracy: 0.6778 - 50ms/epoch - 921us/step
# Epoch 79/150
# 54/54 - 0s - loss: 0.5708 - Accuracy: 0.6909 - 50ms/epoch - 920us/step
# Epoch 80/150
# 54/54 - 0s - loss: 0.5694 - Accuracy: 0.6872 - 48ms/epoch - 882us/step
# Epoch 81/150
# 54/54 - 0s - loss: 0.5677 - Accuracy: 0.6890 - 49ms/epoch - 908us/step
# Epoch 82/150
# 54/54 - 0s - loss: 0.5753 - Accuracy: 0.7002 - 51ms/epoch - 940us/step
# Epoch 83/150
# 54/54 - 0s - loss: 0.5718 - Accuracy: 0.6834 - 51ms/epoch - 949us/step
# Epoch 84/150
# 54/54 - 0s - loss: 0.5666 - Accuracy: 0.6946 - 51ms/epoch - 939us/step
# Epoch 85/150
# 54/54 - 0s - loss: 0.5894 - Accuracy: 0.6629 - 49ms/epoch - 906us/step
# Epoch 86/150
# 54/54 - 0s - loss: 0.5715 - Accuracy: 0.6909 - 51ms/epoch - 942us/step
# Epoch 87/150
# 54/54 - 0s - loss: 0.5600 - Accuracy: 0.6834 - 53ms/epoch - 987us/step
# Epoch 88/150
# 54/54 - 0s - loss: 0.5588 - Accuracy: 0.6853 - 46ms/epoch - 859us/step
# Epoch 89/150
# 54/54 - 0s - loss: 0.5669 - Accuracy: 0.6890 - 46ms/epoch - 843us/step
# Epoch 90/150
# 54/54 - 0s - loss: 0.5678 - Accuracy: 0.6946 - 49ms/epoch - 912us/step
# Epoch 91/150
# 54/54 - 0s - loss: 0.5602 - Accuracy: 0.6890 - 53ms/epoch - 977us/step
# Epoch 92/150
# 54/54 - 0s - loss: 0.5644 - Accuracy: 0.6834 - 51ms/epoch - 953us/step
# Epoch 93/150
# 54/54 - 0s - loss: 0.5661 - Accuracy: 0.6816 - 51ms/epoch - 952us/step
# Epoch 94/150
# 54/54 - 0s - loss: 0.5787 - Accuracy: 0.6909 - 60ms/epoch - 1ms/step
# Epoch 95/150
# 54/54 - 0s - loss: 0.5594 - Accuracy: 0.7039 - 58ms/epoch - 1ms/step
# Epoch 96/150
# 54/54 - 0s - loss: 0.5632 - Accuracy: 0.7076 - 62ms/epoch - 1ms/step
# Epoch 97/150
# 54/54 - 0s - loss: 0.5633 - Accuracy: 0.6983 - 60ms/epoch - 1ms/step
# Epoch 98/150
# 54/54 - 0s - loss: 0.5745 - Accuracy: 0.6909 - 56ms/epoch - 1ms/step
# Epoch 99/150
# 54/54 - 0s - loss: 0.5621 - Accuracy: 0.7020 - 48ms/epoch - 888us/step
# Epoch 100/150
# 54/54 - 0s - loss: 0.5595 - Accuracy: 0.7020 - 54ms/epoch - 997us/step
# Epoch 101/150
# 54/54 - 0s - loss: 0.5683 - Accuracy: 0.7002 - 51ms/epoch - 941us/step
# Epoch 102/150
# 54/54 - 0s - loss: 0.5610 - Accuracy: 0.6965 - 51ms/epoch - 953us/step
# Epoch 103/150
# 54/54 - 0s - loss: 0.5611 - Accuracy: 0.6927 - 69ms/epoch - 1ms/step
# Epoch 104/150
# 54/54 - 0s - loss: 0.5587 - Accuracy: 0.6909 - 75ms/epoch - 1ms/step
# Epoch 105/150
# 54/54 - 0s - loss: 0.5631 - Accuracy: 0.6890 - 60ms/epoch - 1ms/step
# Epoch 106/150
# 54/54 - 0s - loss: 0.5550 - Accuracy: 0.6946 - 65ms/epoch - 1ms/step
# Epoch 107/150
# 54/54 - 0s - loss: 0.5541 - Accuracy: 0.6946 - 61ms/epoch - 1ms/step
# Epoch 108/150
# 54/54 - 0s - loss: 0.5761 - Accuracy: 0.6834 - 60ms/epoch - 1ms/step
# Epoch 109/150
# 54/54 - 0s - loss: 0.5676 - Accuracy: 0.6946 - 62ms/epoch - 1ms/step
# Epoch 110/150
# 54/54 - 0s - loss: 0.5609 - Accuracy: 0.7002 - 56ms/epoch - 1ms/step
# Epoch 111/150
# 54/54 - 0s - loss: 0.5758 - Accuracy: 0.6872 - 59ms/epoch - 1ms/step
# Epoch 112/150
# 54/54 - 0s - loss: 0.5558 - Accuracy: 0.6946 - 64ms/epoch - 1ms/step
# Epoch 113/150
# 54/54 - 0s - loss: 0.5546 - Accuracy: 0.6983 - 101ms/epoch - 2ms/step
# Epoch 114/150
# 54/54 - 0s - loss: 0.5620 - Accuracy: 0.6946 - 77ms/epoch - 1ms/step
# Epoch 115/150
# 54/54 - 0s - loss: 0.5522 - Accuracy: 0.7039 - 48ms/epoch - 891us/step
# Epoch 116/150
# 54/54 - 0s - loss: 0.5487 - Accuracy: 0.7039 - 36ms/epoch - 667us/step
# Epoch 117/150
# 54/54 - 0s - loss: 0.5590 - Accuracy: 0.6853 - 56ms/epoch - 1ms/step
# Epoch 118/150
# 54/54 - 0s - loss: 0.5587 - Accuracy: 0.6909 - 55ms/epoch - 1ms/step
# Epoch 119/150
# 54/54 - 0s - loss: 0.5555 - Accuracy: 0.7058 - 64ms/epoch - 1ms/step
# Epoch 120/150
# 54/54 - 0s - loss: 0.5559 - Accuracy: 0.6946 - 72ms/epoch - 1ms/step
# Epoch 121/150
# 54/54 - 0s - loss: 0.5595 - Accuracy: 0.7039 - 67ms/epoch - 1ms/step
# Epoch 122/150
# 54/54 - 0s - loss: 0.5520 - Accuracy: 0.6983 - 61ms/epoch - 1ms/step
# Epoch 123/150
# 54/54 - 0s - loss: 0.5525 - Accuracy: 0.6983 - 62ms/epoch - 1ms/step
# Epoch 124/150
# 54/54 - 0s - loss: 0.5504 - Accuracy: 0.7039 - 63ms/epoch - 1ms/step
# Epoch 125/150
# 54/54 - 0s - loss: 0.5548 - Accuracy: 0.6983 - 71ms/epoch - 1ms/step
# Epoch 126/150
# 54/54 - 0s - loss: 0.5520 - Accuracy: 0.6890 - 64ms/epoch - 1ms/step
# Epoch 127/150
# 54/54 - 0s - loss: 0.5461 - Accuracy: 0.6983 - 67ms/epoch - 1ms/step
# Epoch 128/150
# 54/54 - 0s - loss: 0.5438 - Accuracy: 0.7076 - 65ms/epoch - 1ms/step
# Epoch 129/150
# 54/54 - 0s - loss: 0.5497 - Accuracy: 0.7076 - 62ms/epoch - 1ms/step
# Epoch 130/150
# 54/54 - 0s - loss: 0.5492 - Accuracy: 0.7039 - 67ms/epoch - 1ms/step
# Epoch 131/150
# 54/54 - 0s - loss: 0.5510 - Accuracy: 0.6946 - 66ms/epoch - 1ms/step
# Epoch 132/150
# 54/54 - 0s - loss: 0.5433 - Accuracy: 0.7076 - 70ms/epoch - 1ms/step
# Epoch 133/150
# 54/54 - 0s - loss: 0.5483 - Accuracy: 0.7020 - 66ms/epoch - 1ms/step
# Epoch 134/150
# 54/54 - 0s - loss: 0.5460 - Accuracy: 0.7076 - 61ms/epoch - 1ms/step
# Epoch 135/150
# 54/54 - 0s - loss: 0.5585 - Accuracy: 0.7002 - 63ms/epoch - 1ms/step
# Epoch 136/150
# 54/54 - 0s - loss: 0.5491 - Accuracy: 0.7132 - 64ms/epoch - 1ms/step
# Epoch 137/150
# 54/54 - 0s - loss: 0.5471 - Accuracy: 0.7058 - 61ms/epoch - 1ms/step
# Epoch 138/150
# 54/54 - 0s - loss: 0.5484 - Accuracy: 0.7076 - 59ms/epoch - 1ms/step
# Epoch 139/150

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis = 1)
accuracy_score(y_test,y_pred)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)

# %%
history.history.keys()

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.xlabel('epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')
